# %% [markdown]
# ## Task
#  1. Read the dataset(https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv) (advertisement.csv)
#  2. Perform analysis on dataset
#  3. Handling the duplicates and null values in the dataset
#  4. Standardize the dataset by using different scaling methods
#  5. Plot the dataset
#  6. Visualize the relationship between any input feature and target
#  7. Visualize the relationship between all input features and target

# %% [markdown]
# ## Day Agenda
#
# - cubehelix palette observations using hist map
# - Different styles of plots in seaborn
#     - Catagorical scatter plots
#         - Strip plot
#         - swarm plot
#     - Categorical distibuted plots
#         - histogram
#         - Box plot
#         - kde plots
#         - voilin plots
#     - Estimated plots
#         - bar
#         - point point
#         - count plot
#
# - joint plot
# - pair plot

# %%
import seaborn as sns
import numpy as np
x=np.random.randint(1,20,10).reshape(2,5)
c=sns.cubehelix_palette(as_cmap=True)
sns.heatmap(x,cmap=c)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(x,annot=True,linewidth=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Catagorical scatter plots
#         - Strip plot
#         - swarm plot

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.groupby(by='species').sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        171.4          73.1         12.3
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
sns.catplot(x='sepal_length',y='petal_length',data=df,hue='petal_width')

# %%
sns.catplot(x='sepal_length',y='petal_length',data=df,hue='species')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind="box")

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind="bar")

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind="bar",palette=['r','g','b'])

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind="bar",palette=['r','g','b'],col="species")

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind="violin",palette=['r','g','b'],col="species")

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',palette=['r','g','b'],marker='^')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind="boxen",palette=['r','g','b'],col="species")

# %% [markdown]
#  ## Categorical distibuted plots
#         - histogram
#         - Box plot
#         - kde plots
#         - voilin plots

# %% [markdown]
# ##  histogram plot

# %%
df1=sns.load_dataset("tips")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.histplot(data=df1)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=df1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='sex',data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=df1,bins=5)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(y='total_bill',data=df1,bins=5,binwidth=3)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(x='total_bill',data=df1,kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=df1,kde=True,hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>
